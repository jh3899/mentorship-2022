# %%
import pandas as pd
pd.set_option("display.max_columns", 999)

# %%
mentees = pd.read_csv('mentee(1).csv')
mentees.head()
# Out:
#             Timestamp               Full Name       Drexel Email  Gender  \
# 0  9/24/2022 21:00:43              Charles Wu   Cyw37@drexel.edu    Male
# 1  9/26/2022 16:59:00                Joy Wong  jw3745@drexel.edu  Female
# 2  9/27/2022 20:55:12  Athela Grace Villaruel   acv63@drexel.edu  Female
# 3  9/28/2022 16:59:05             Ansh Kapoor  ak4352@drexel.edu    Male
# 4  9/28/2022 21:09:49          Sindhu Raghava  sr3628@drexel.edu  Female
#
#                      Year in Drexel                    Major Concentration  \
# 0                         Sophomore                 Comp Sci         ML/AI
# 1  transfer student pre-junior year          B.S. in Nursing           NaN
# 2                          Freshman         Computer Science           NaN
# 3                          Freshman  Mechanical engineering            NaN
# 4                          Freshman                 Business           NaN
#
#   Minor     Briefly Describe yourself (~100 words or less)  \
# 0  Math  I'm an international student from Brazil, but ...
# 1   NaN  I may look calm and collected on the outside b...
# 2   NaN  I am a short girl who laughs easily and is fri...
# 3   NaN  A person who is not just confident and respons...
# 4   NaN  I am a freshman at Drexel majoring in business...
#
#   Briefly describe your career goals (~50 words or less)  \
# 0  \nMy career goal, for now, is to be able to ge...
# 1  To make a decision on whether or not to change...
# 2  I want to graduate with a bachelor's degree in...
# 3  \n\nDesigning sleek solutions, imagining possi...
# 4  I’m still not 100% sure if I want to be a doct...
#
#   Briefly describe your interests (~50 words or less)  \
# 0  I enjoy many hobbies but lately the ones that ...
# 1  volleyball (& trying out other physical activi...
# 2  I like watching gaming videos on youtube and w...
# 3  - Learning new things\n- Reading newspapers \n...
# 4                                                NaN
#
#   What are you looking for in a mentor? (This could be professional, academic, personal, or anything else, we just want a general idea. ~100 words or less)  \
# 0  What I look for in a mentor is who could help ...
# 1  I'm indecisive so generally I need different o...
# 2  I am looking for a mentor who will be a good, ...
# 3  The one who motivates everyone. He/ she should...
# 4  I want someone who can guide me in different a...
#
#   Please upload a photo of yourself to put onto our website's mentee page. ONLY .PNG or .JPG photos please and name it as "First Name_Last Name" (ex. Christine_Su.JPG)  \
# 0  https://drive.google.com/open?id=1-CoHW0mFvzsi...
# 1  https://drive.google.com/open?id=1zJV-Zks7sfpL...
# 2  https://drive.google.com/open?id=11eoyygYEJcFU...
# 3  https://drive.google.com/open?id=1N4ivjFtthWTJ...
# 4  https://drive.google.com/open?id=1xehkCtZu5D1z...
#
#   I agree that I will attend at least 2 out of the 5 SASE mentorship week events.  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Which of the mentorship events are you planning on attending?  \
# 0  Speed-Dating (Mon. 10/24 & Tues. 10/25 @ 6-8pm...
# 1  Speed-Dating (Mon. 10/24 & Tues. 10/25 @ 6-8pm...
# 2  Speed-Dating (Mon. 10/24 & Tues. 10/25 @ 6-8pm...
# 3  Speed-Dating (Mon. 10/24 & Tues. 10/25 @ 6-8pm...
# 4  Mentorship Game Night, SASE B-Day Bash (Fri. 1...
#
#   I have read, understood, and can abide by the deadlines to participate in the mentorship program (Deadlines can be found on our mentorship page on our website: https://sase-drexel.weebly.com/mentorship-program.html)  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Any questions or comments?
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
mentees = mentees.rename(columns={'Briefly Describe yourself (~100 words or less)': "About",
       'Briefly describe your career goals (~50 words or less)': "Career",
       'Briefly describe your interests (~50 words or less)': "Interests",
       'What are you looking for in a mentor? (This could be professional, academic, personal, or anything else, we just want a general idea. ~100 words or less)': "Looking for",})

mentees = mentees.fillna("None")

# %%
for i in range(0, len(mentees)):
    full_name = mentees['Full Name'][i]
    date = '2022-10-20'
    first_name = mentees['Full Name'][i].split()[0]
    last_name = mentees['Full Name'][i].split()[1]
    year = mentees['Year in Drexel'][i]
    major = mentees['Major'][i]
    about = mentees['About'][i]
    career = mentees['Career'][i]
    interests = mentees['Interests'][i]
    looking_for = mentees['Looking for'][i]
    
    markdown =  '''---
layout: post
title: {} 
date: {}
image: assets/images/{}_{} - {} {}.jpg
about: {}
year: {}
major: {}

---

### About

{}

### Career Goals

{}

### Interests

{}

### Looking For

{}

<div class="text-center my-5">
    <img src="https://sase-drexel.github.io/mentorship-2021/assets/images/{}_{}.jpg" alt="{}" class="rounded post-img" />
</div>
'''.format(full_name, date, first_name, last_name, first_name, last_name, about, year, major, about, career, interests, looking_for, first_name, last_name, full_name)
    
    mentee_profile = open("{}-{}-{}.md".format(date, first_name, last_name), "w", encoding='utf-8')
    new_profile = mentee_profile.write(markdown)
    mentee_profile.close()

# %%
mentors = pd.read_csv('mentor.csv')
mentors.head()
# Out:
#              Timestamp       Full Name       Drexel Email Gender Drexel Year  \
# 0  10/19/2022 18:19:51  Aaron Alquiros   ata65@drexel.edu   Male      Senior
# 1   10/21/2022 0:23:37     Abbas Mirza  aam444@drexel.edu   Male      Senior
# 2  10/18/2022 18:23:35    Alain Nguyen   aln65@drexel.edu   Male      Senior
# 3  10/20/2022 23:37:30      Alan Zheng   az523@drexel.edu   Male      Junior
# 4  10/10/2022 23:55:42    Albert Leung  al3369@drexel.edu   Male      Senior
#
#                       Major                        Concentration  \
# 0    Engineering Technology                                  NaN
# 1    Mechanical Engineering                                  NaN
# 2                  Business  Operations/Supply Chain Management
# 3  Business and Engineering                             Robotics
# 4       Information Systems                                  NaN
#
#                       Minor  \
# 0                       NaN
# 1                       NaN
# 2       Business Analytics
# 3                       MIS
# 4  Business Administration
#
#              If applicable, list out previous co-ops  \
# 0                                                NaN
# 1           Coop 1: CPMI\nCoop 2: Horiba Instruments
# 2  PECO- Electronic Operations Analyst\nTromner- ...
# 3                      Real Estate, Executive Search
# 4  Philadelphia Streets Department, Lockheed Mart...
#
#    Why do you want to be a SASE Mentor? (<100 words)  \
# 0  I am an old senior 5/5 😔 electrical engineerin...
# 1  Angel angel angel angel angel angel angel ange...
# 2  This boutta be professional af: As a SASE Ment...
# 3                                     Cause why not?
# 4  I've been a part of SASE since I was a freshma...
#
#   How do you plan to mentor your SASE Mentee? (<100 words)  \
# 0                                                NaN
# 1  I plan to be the best mentor ever seen on the ...
# 2  I guess i'll be like being supportive and stuf...
# 3  We could hang out, explore the city, and talk ...
# 4  I plan to mentor my mentee with the experience...
#
#                Briefly describe yourself (<50 words)  \
# 0                                              bread
# 1  I am always willing to learn something new and...
# 2  I am 6'. I finally been able to poop once a da...
# 3  Hey, I’m Alan and I am a Philly native. I migh...
# 4  I would say I’m pretty chill and a down-to-ear...
#
#             What are your career goals? (< 50 words)  \
# 0                                                NaN
# 1  I wish to get research and development job som...
# 2  I don't dream of work because I don't dream of...
# 3                                       Retire Early
# 4  I want to be successful, happy, and passionate...
#
#        What are some of your interests? (< 50 words)  \
# 0  Listening to Niki and also some other music ar...
# 1  Playing guitar, video games, climbing, biking,...
# 2  thrifting, making spotify playlist, badminton,...
# 3  I like skating, biking, playing games, and eat...
# 4  Some of my interests are playing basketball, w...
#
#   How do you envision your relationship with your mentee?  \
# 0  I'm looking for someone that can take pictures...
# 1  I am honestly not entirely sure but I do belie...
# 2  I would be someone to talk to any time, this'd...
# 3  I think it would be fun to have a laid back re...
# 4  I envision myself acting as a friend - someone...
#
#   Please upload a photo of yourself to put onto our website's mentor page. ONLY .PNG or .JPG photos please and name it as "First Name_Last Name" (ex. Christine_Su.JPG)  \
# 0  https://drive.google.com/open?id=1srzr2Vp_SAyC...
# 1  https://drive.google.com/open?id=16VaPET_91VOy...
# 2  https://drive.google.com/file/d/18Floa2L2kRWBb...
# 3  https://drive.google.com/open?id=1Y_nAfQTQkmPV...
# 4  https://drive.google.com/open?id=1pJ291LUrkt1t...
#
#   I agree that I will attend at least 2 out of the 5 SASE mentorship week events.  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Which of the mentorship events are you planning on attending?  \
# 0  Speed-Dating (Mon. 10/24 & Tues. 10/25 @ 6-8pm...
# 1    Speed-Dating (Mon. 10/24 & Tues. 10/25 @ 6-8pm)
# 2  Speed-Dating (Mon. 10/24 & Tues. 10/25 @ 6-8pm...
# 3  Speed-Dating (Mon. 10/24 & Tues. 10/25 @ 6-8pm...
# 4  Speed-Dating (Mon. 10/24 & Tues. 10/25 @ 6-8pm...
#
#   I am open to taking on a 2nd mentee (if necessary)  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   I acknowledge that I may not be paired with a mentee if there's a huge imbalance in the ratio of mentors to mentees.  \
# 0                                                NaN
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   I have read, understood, and can abide by the deadlines to participate in the mentorship program (Deadlines can be found on our mentorship page on our website: https://sase-drexel.weebly.com/mentorship-program.html)  \
# 0                                                NaN
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Any comments/concerns/questions?
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %%
mentors = mentors.rename(columns={'Briefly describe yourself (<50 words)': "About",
        'Why do you want to be a SASE Mentor? (<100 words)': "Why do I want to be a SASE mentor?",
        'How do you plan to mentor your SASE Mentee? (<100 words)': 'What to expect',
       'What are your career goals? (< 50 words)': "Career",
       'If applicable, list out previous co-ops': "Co-ops",
       'What are some of your interests? (< 50 words)': "Interests",
       'How do you envision your relationship with your mentee?': "Relationship"
        })

mentors = mentors.fillna("None")

# %%
for i in range(len(mentors)-2, len(mentors)):
    full_name = mentors['Full Name'][i]
    date = '2022-10-20'
    first_name = mentors['Full Name'][i].split()[0]
    last_name = mentors['Full Name'][i].split()[1]
    year = mentors['Drexel Year'][i]
    major = mentors['Major'][i]
    about = mentors['About'][i]
    why = mentors['Why do I want to be a SASE mentor?'][i]
    career = mentors['Career'][i]
    co_ops = mentors['Co-ops'][i]
    interests = mentors['Interests'][i]
    what_to_expect = mentors['What to expect'][i]
    relationship = mentors['Relationship'][i]

    markdown =  '''---
layout: post
title: {} 
date: {}
image: assets/images/{}-{} - {} {}.jpg
about: {}
year: {}
major: {}

---

### About

{}

### Why Do I Want To Be a SASE Mentor?

{}

### Career Goals

{}

### Co-ops

{}

### Interests

{}

### What to Expect From Me

{}

### How I Envision My Relationship With My Mentee(s) 

{}

<div class="text-center my-5">
    <img src="https://sase-drexel.github.io/mentorship-2021/assets/images/{}_{}.jpg" alt="{}" class="rounded post-img" />
</div>
'''.format(full_name, date, first_name, last_name, first_name, last_name, about, year, major, about, why, career, co_ops, interests, what_to_expect, relationship, first_name, last_name, full_name)
    
    mentor_profile = open("{}-{}-{}.md".format(date, first_name, last_name), "w", encoding='utf-8')
    new_profile = mentor_profile.write(markdown)
    mentor_profile.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [9], line 5
#       3 date = '2022-10-20'
#       4 first_name = mentors['Full Name'][i].split()[0]
# ----> 5 last_name = mentors['Full Name'][i].split()[1]
#       6 year = mentors['Drexel Year'][i]
#       7 major = mentors['Major'][i]
#
# IndexError: list index out of range

# %%
mentee_emails = list(mentees['Drexel Email'].values)
mentor_emails = list(mentors['Drexel Email'].values)

print('MENTEE EMAILS')
for mentee in mentee_emails:
    print(mentee, end = ', ')
    
print('\n\nMENTOR EMAILS')
for mentor in mentor_emails:
    print(mentor, end = ', ')
# Out:
# MENTEE EMAILS
# Cyw37@drexel.edu, jw3745@drexel.edu, acv63@drexel.edu, ak4352@drexel.edu, sr3628@drexel.edu, bmn48@drexel.edu, mjs685@drexel.edu, ahh55@drexel.edu, ml3757@drexel.edu, fn87@drexel.edu, Aw3477@drexel.edu, kw987@drexel.edu, as583@drexel.edu, hsy23@drexel.edu, rmt67@drexel.edu, epl38@drexel.edu, yihuan.yang@drexel.edu, sg3759@drexel.edu, ac4393@drexel.edu, rc3297@drexel.edu, acc385@drexel.edu, vc454@drexel.com, lg849@drexel.edu, ar3863@drexel.edu, hk835@drexel.edu, vtn35@drexel.edu, jy583@drexel.edu, jy585@drexel.edu, emt94@drexel.edu, ahm89@drexel.edu, cle55@drexel.edu, jg3798@drexel.edu, jja94@drexel.edu, tvk26@drexel.edu, sg3774@drexel.edu, aw3487@drexel.edu, bp578@drexel.edu, sn924@drexel.edu, rhn29@drexel.edu, jk3784@drexel.edu, Vdl29@drexel.edu, jo633@drexel.edu, cs3834@drexel.edu, Vs633@drexel.edu , cn527@drexel.edu, ptn39@drexel.edu, eh658@drexel.edu, kt828@drexel.edu, jj3247@drexel.edu, chv27@drexel.edu, ey338@drexel.edu,
#
# MENTOR EMAILS
# mnt43@drexel.edu, nrh48@drexel.edu, Bl655@drexel.edu, dkl64@drexel.edu, jdn59@drexel.edu, al3369@drexel.edu, wc492@drexel.edu, atb87@drexel.edu, jt3348@drexel.edu , bn389@drexel.edu, na874@drexel.edu, rhn26@drexel.edu, jt964@drexel.edu, mc4346@drexel.edu, ml3725@drexel.edu, th943@drexel.edu, acc374@drexel.edu, kw875@drexel.edu, eg586@drexel.edu, kl3272@drexel.edu, jc3927@gmail.com, aln65@drexel.edu, sy569@drexel.edu, al3462@drexel.edu, spa38@drexel.edu, mn698@drexel.edu, jh3899@drexel.edu, fy72@drexel.edu, jh3665@drexel.edu, Jyl57@drexel.edu, sc3985@drexel.edu, sm4595@drexel.edu, kq56@drexel.edu, chs59@drexel.edu, cw3238@drexel.edu, na868@drexel.edu, at3349@drexel.edu, cw3266@drexel.edu, kl3373@drexel.edu, ht377@drexel.edu, az523@drexel.edu, sp3825@gmail.com, aam444@drexel.edu, ata65@drexel.edu,

# %%
# Out:
# None
